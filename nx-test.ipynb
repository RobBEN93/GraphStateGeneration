# %%
from yaml_to_nx import yaml_to_nx, visualize_graph, shortest_path

# %%
G = yaml_to_nx(filename="network_configs/smallworldnetwork.yaml")

# %%
print(G)
# Out:
# Graph with 10 nodes and 20 edges

# %%
G.nodes()
# Out:
# NodeView(('node_0', 'node_1', 'node_2', 'node_3', 'node_4', 'node_5', 'node_6', 'node_7', 'node_8', 'node_9'))

# %%
visualize_graph(G)

# %%
shortest_path(G,("node_1","node_8"))
# Out:
# ['node_1', 'node_0', 'node_8']
