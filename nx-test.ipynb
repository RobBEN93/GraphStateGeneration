# %%
from yaml_to_nx import yaml_to_nx, visualize_graph, shortest_path

# %%
G = yaml_to_nx(filename="smallworldnetwork.yaml")

# %%
print(G)
# Out:
# Graph with 10 nodes and 20 edges

# %%
something = G.nodes()

# %%
print(something)
# Out:
# ['node_a', 'node_b', 'node_c', 'node_d', 'node_e', 'node_f', 'node_g', 'node_h', 'node_i', 'node_j']

# %%
path = shortest_path(G,('node_g', 'node_h'))

# %%
path
# Out:
# ['node_g', 'node_h']

# %%
visualize_graph(G)
