# %%
from yaml_to_nx import yaml_to_nx, visualize_graph, shortest_path

# %%
G = yaml_to_nx(filename="/home/vor/VSCodeProjects/QIA-Challenge/smallworldtennodeconfig.yaml")

# %%
print(G)
# Out:
# Graph with 10 nodes and 20 edges

# %%
path = shortest_path(G,('node_6', 'node_4'))

# %%
path
# Out:
# ['node_6', 'node_0', 'node_1', 'node_4']

# %%
visualize_graph(G)

# %% [markdown]
# Say we want to generate a graph state corresponding to the graph G = (V,E), V = ['node_0','node_1','node_2','node_7','node_9'], E = [('node_0','node_1'),('node_1','node_2'),('node_0','node_7'),('node_2','node_9')]
